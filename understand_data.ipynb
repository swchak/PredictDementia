# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

patient_health_data = pd.read_csv('~/projects/pytorch/PredictDementia/dementia_patients_health_data 2.csv')
       
# print(patient_health_data.head(10))
patient_health_data.shape

sns.histplot(data=patient_health_data, y='Dosage in mg', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, y='Education_Level', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, y='Dominant_Hand', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, y='Chronic_Health_Conditions', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, x='Medication_History', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, y='Family_History', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, y='Smoking_Status', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, y='Gender', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, x='Cognitive_Test_Scores', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, x='Depression_Status', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, x='Diabetic', hue="Dementia", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, y='Dementia', hue="Physical_Activity", multiple="dodge")

plt.show()
sns.histplot(data=patient_health_data, y='APOE_ε4', hue="Dementia", multiple="dodge")

plt.show()
sns.histplot(data=patient_health_data, x='Sleep_Quality', hue="Dementia", multiple="dodge")
plt.show()

sns.histplot(data=patient_health_data, x="Prescription", multiple="dodge")
plt.show()
sns.histplot(data=patient_health_data, x="Age", hue="Dementia", multiple="dodge")
plt.show()

sns.catplot(data=patient_health_data, y="Nutrition_Diet", hue="Dementia", kind="box")
